# %%
pip install visualiser
# Out:
# Collecting visualiser
#   Using cached visualiser-1.2.tar.gz (3.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting librosa (from visualiser)
#   Using cached librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting pydub (from visualiser)
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting numpy (from visualiser)
#   Downloading numpy-2.3.0-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting pygame (from visualiser)
#   Downloading pygame-2.6.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting audioread>=2.1.9 (from librosa->visualiser)
#   Using cached audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting numba>=0.51.0 (from librosa->visualiser)
#   Downloading numba-0.61.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting scipy>=1.6.0 (from librosa->visualiser)
#   Downloading scipy-1.15.3-cp313-cp313-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting scikit-learn>=1.1.0 (from librosa->visualiser)
#   Downloading scikit_learn-1.7.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (31 kB)
# Collecting joblib>=1.0 (from librosa->visualiser)
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: decorator>=4.3.0 in /opt/homebrew/Cellar/jupyterlab/4.4.3_2/libexec/lib/python3.13/site-packages (from librosa->visualiser) (5.2.1)
# Collecting soundfile>=0.12.1 (from librosa->visualiser)
#   Using cached soundfile-0.13.1-py2.py3-none-macosx_11_0_arm64.whl.metadata (16 kB)
# Collecting pooch>=1.1 (from librosa->visualiser)
#   Using cached pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa->visualiser)
#   Downloading soxr-0.5.0.post1-cp312-abi3-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Requirement already satisfied: typing_extensions>=4.1.1 in /opt/homebrew/Cellar/jupyterlab/4.4.3_2/libexec/lib/python3.13/site-packages (from librosa->visualiser) (4.14.0)
# Collecting lazy_loader>=0.1 (from librosa->visualiser)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting msgpack>=1.0 (from librosa->visualiser)
#   Downloading msgpack-1.1.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.4 kB)
# Collecting standard-aifc (from librosa->visualiser)
#   Downloading standard_aifc-3.13.0-py3-none-any.whl.metadata (969 bytes)
# Collecting standard-sunau (from librosa->visualiser)
#   Downloading standard_sunau-3.13.0-py3-none-any.whl.metadata (914 bytes)
# Requirement already satisfied: packaging in /opt/homebrew/Cellar/jupyterlab/4.4.3_2/libexec/lib/python3.13/site-packages (from lazy_loader>=0.1->librosa->visualiser) (25.0)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba>=0.51.0->librosa->visualiser)
#   Downloading llvmlite-0.44.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Collecting numpy (from visualiser)
#   Downloading numpy-2.2.6-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/homebrew/Cellar/jupyterlab/4.4.3_2/libexec/lib/python3.13/site-packages (from pooch>=1.1->librosa->visualiser) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in /opt/homebrew/Cellar/jupyterlab/4.4.3_2/libexec/lib/python3.13/site-packages (from pooch>=1.1->librosa->visualiser) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Cellar/jupyterlab/4.4.3_2/libexec/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa->visualiser) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Cellar/jupyterlab/4.4.3_2/libexec/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa->visualiser) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Cellar/jupyterlab/4.4.3_2/libexec/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa->visualiser) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/opt/certifi/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa->visualiser) (2025.6.15)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.1.0->librosa->visualiser)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: cffi>=1.0 in /opt/homebrew/Cellar/jupyterlab/4.4.3_2/libexec/lib/python3.13/site-packages (from soundfile>=0.12.1->librosa->visualiser) (1.17.1)
# Requirement already satisfied: pycparser in /opt/homebrew/Cellar/jupyterlab/4.4.3_2/libexec/lib/python3.13/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->visualiser) (2.22)
# Collecting standard-chunk (from standard-aifc->librosa->visualiser)
#   Downloading standard_chunk-3.13.0-py3-none-any.whl.metadata (860 bytes)
# Collecting audioop-lts (from standard-aifc->librosa->visualiser)
#   Downloading audioop_lts-0.2.1-cp313-abi3-macosx_11_0_arm64.whl.metadata (1.6 kB)
# Using cached librosa-0.11.0-py3-none-any.whl (260 kB)
# Using cached audioread-3.0.1-py3-none-any.whl (23 kB)
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading msgpack-1.1.1-cp313-cp313-macosx_11_0_arm64.whl (78 kB)
# Downloading numba-0.61.2-cp313-cp313-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 32.7 MB/s eta 0:00:00
# Downloading llvmlite-0.44.0-cp313-cp313-macosx_11_0_arm64.whl (26.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.2/26.2 MB 67.6 MB/s eta 0:00:00a 0:00:01
# Downloading numpy-2.2.6-cp313-cp313-macosx_14_0_arm64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 73.7 MB/s eta 0:00:00
# Using cached pooch-1.8.2-py3-none-any.whl (64 kB)
# Downloading scikit_learn-1.7.0-cp313-cp313-macosx_12_0_arm64.whl (10.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 65.1 MB/s eta 0:00:00
# Downloading scipy-1.15.3-cp313-cp313-macosx_14_0_arm64.whl (22.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 79.4 MB/s eta 0:00:00a 0:00:01
# Using cached soundfile-0.13.1-py2.py3-none-macosx_11_0_arm64.whl (1.1 MB)
# Downloading soxr-0.5.0.post1-cp312-abi3-macosx_11_0_arm64.whl (156 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading pygame-2.6.1-cp313-cp313-macosx_11_0_arm64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 47.7 MB/s eta 0:00:00 0:00:01
# Downloading standard_aifc-3.13.0-py3-none-any.whl (10 kB)
# Downloading audioop_lts-0.2.1-cp313-abi3-macosx_11_0_arm64.whl (26 kB)
# Downloading standard_chunk-3.13.0-py3-none-any.whl (4.9 kB)
# Downloading standard_sunau-3.13.0-py3-none-any.whl (7.4 kB)
# Building wheels for collected packages: visualiser
#   DEPRECATION: Building 'visualiser' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'visualiser'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for visualiser (setup.py) ... done
#   Created wheel for visualiser: filename=visualiser-1.2-py3-none-any.whl size=4266 sha256=006c34c762da0b14310fd0600b3f58a1cad2fea47120e74b296fa8b330064e3e
#   Stored in directory: /Users/lucasdamaceno/Library/Caches/pip/wheels/03/67/ff/ff1fc4f36a455671b94e3c300a53c35f3634e44dd5f8185b9c
# Successfully built visualiser
# Installing collected packages: standard-chunk, pydub, threadpoolctl, pygame, numpy, msgpack, llvmlite, lazy_loader, joblib, audioread, audioop-lts, standard-sunau, standard-aifc, soxr, soundfile, scipy, pooch, numba, scikit-learn, librosa, visualiser
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21/21 [visualiser]1 [librosa]earn]
# Successfully installed audioop-lts-0.2.1 audioread-3.0.1 joblib-1.5.1 lazy_loader-0.4 librosa-0.11.0 llvmlite-0.44.0 msgpack-1.1.1 numba-0.61.2 numpy-2.2.6 pooch-1.8.2 pydub-0.25.1 pygame-2.6.1 scikit-learn-1.7.0 scipy-1.15.3 soundfile-0.13.1 soxr-0.5.0.post1 standard-aifc-3.13.0 standard-chunk-3.13.0 standard-sunau-3.13.0 threadpoolctl-3.6.0 visualiser-1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from typing import List
from visualiser import Visualiser as vs

class Game:
    @vs
    def entry(self, nums: List[int]) -> bool:
        num_list = [float(num) for num in nums] # convert eveything to float
        return self.dfs(num_list)

    def dfs(self, nums: List[float]) -> bool:
        if len(nums) == 0:
            return False
        if len(nums) == 1:
            return abs(nums[0] - 24.0) < 0.00001 #means it equals 24 or near enough

        for i in range(len(nums)):
            for j in range(i + 1, len(nums)): # combine operations between two neighboring numbers
                for operation in range(6):
                    next_list = self.do_operation(nums, i, j, operation)
                    if next_list and self.dfs(next_list):
                        return True
        return False

    def do_operation(self, nums: List[float], i: int, j: int, operation: int) -> List[float]:
        next_list = [nums[k] for k in range(len(nums)) if k != i and k != j]

        if operation == 0:
            next_list.append(nums[i] + nums[j])
        elif operation == 1:
            next_list.append(nums[i] - nums[j])
        elif operation == 2:
            next_list.append(nums[j] - nums[i])
        elif operation == 3:
            next_list.append(nums[i] * nums[j])
        elif operation == 4:
            if nums[j] != 0:
                next_list.append(nums[i] / nums[j])
            else:
                return []
        elif operation == 5:
            if nums[i] != 0:
                next_list.append(nums[j] / nums[i])
            else:
                return []

        return next_list

input = [4, 3, 2, 1]
Game().entry(input)
vs.make_animation("24game.gif", delay=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 49
#      46         return next_list
#      48 input = [4, 3, 2, 1]
# ---> 49 Game().entry(input)
#      50 vs.make_animation("24game.gif", delay=2)
#
# Cell In[11], line 7, in Game.entry(self, nums)
#       5 def entry(self, nums: List[int]) -> bool:
#       6     num_list = [float(num) for num in nums] # convert eveything to float
# ----> 7     return self.dfs(num_list)
#
# TypeError: 'Visualiser' object is not callable

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from rcviz import CallGraph, viz
#
# ModuleNotFoundError: No module named 'rcviz'
